# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
heart_df = pd.read_csv("../data/heart.csv")
otwo_df = pd.read_csv("../data/o2Saturation.csv")

# %%
print(f"{"="*20} SHAPE {"="*20}")
print(f" heart_df : {heart_df.shape}\n otwo_df : {otwo_df.shape}")

print(f"{"="*20} DTYPES {"="*20}")
print(f" heart_df : {heart_df.dtypes}\n\n\n otwo_df : {otwo_df.dtypes}")
# Out:
# ==================== SHAPE ====================
#  heart_df : (303, 14)
#  otwo_df : (3585, 1)
# ==================== DTYPES ====================
#  heart_df : age           int64
# sex           int64
# cp            int64
# trtbps        int64
# chol          int64
# fbs           int64
# restecg       int64
# thalachh      int64
# exng          int64
# oldpeak     float64
# slp           int64
# caa           int64
# thall         int64
# output        int64
# dtype: object
#
#
#  otwo_df : 98.6    float64
# dtype: object

# %%
print(f"{"="*20} VALEUR MANQUANTE {"="*20}")
print(f"heart_df : {heart_df.isnull().sum()}\n\n\n otwo_df : {otwo_df.isnull().sum()}")
# Out:
# ==================== VALEUR MANQUANTE ====================
# heart_df : age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64
#
#
#  otwo_df : 98.6    0
# dtype: int64

# %%
heart_df["output"].value_counts()
# Out:
# output
# 1    165
# 0    138
# Name: count, dtype: int64

# %%
sns.heatmap(heart_df.corr(), annot = True, fmt=".1f")
# Out:
# <Axes: >

# %%
fig, axes = plt.subplot(len())
sns.boxplot(data=heart_df, x="age", hue="output")
plt.show()
sns.boxplot(data=heart_df, x="trtbps", hue="output")
sns.boxplot(data=heart_df, x="chol", hue="output")
sns.boxplot(data=heart_df, x="thalachh", hue="output")
sns.boxplot(data=heart_df, x="oldpeak", hue="output")
# Out:
# <Axes: xlabel='chol'>
